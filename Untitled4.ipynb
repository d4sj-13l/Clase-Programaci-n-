# %% [markdown]
# Escriba un programa que dada una fecha del año 2000 (representada por el día, mes y año en formato numérico dd/mm/aaa) calcule el día siguiente. Se asumen que el mes tiene 30 días

# %%
print("Ingrese ")
